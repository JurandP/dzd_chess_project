# %%
import pandas as pd

df = pd.read_csv('../lichess_db_puzzle.csv')

# %%
df
# Out:
#         PuzzleId                                                FEN  \
# 0          00008  r6k/pp2r2p/4Rp1Q/3p4/8/1N1P2R1/PqP2bPP/7K b - ...
# 1          0000D  5rk1/1p3ppp/pq3b2/8/8/1P1Q1N2/P4PPP/3R2K1 w - ...
# 2          0008Q       8/4R3/1p2P3/p4r2/P6p/1P3Pk1/4K3/8 w - - 1 64
# 3          0009B  r2qr1k1/b1p2ppp/pp4n1/P1P1p3/4P1n1/B2P2Pb/3NBP...
# 4          000Vc             8/8/4k1p1/2KpP2p/5PP1/8/8/8 w - - 0 53
# ...          ...                                                ...
# 3888760    zzzc4   3r3k/p5pp/8/5R2/1BQ1p3/P3q3/Bb4PP/6K1 w - - 0 28
# 3888761    zzzco  5Q2/pp3R1P/1kpp4/4p3/2P1P3/3PP2P/Pr2q3/2K5 w -...
# 3888762    zzzhI  r3kb1r/ppp2ppp/2n5/3q3b/3P1B2/5N1P/PPP3P1/RN1Q...
# 3888763    zzzhg  r2q1rk1/4bppp/p1n1pn2/1p1pN3/2pP2b1/1PP1P3/PBQ...
# 3888764    zzzw8           8/p7/2Kn4/4k1p1/6Pp/2PB3P/8/8 b - - 3 42
#
#                                  Moves  Rating  RatingDeviation  Popularity  \
# ...

# %%
df_test = pd.read_csv('../test_data_set.csv')

df_test
# Out:
#      PuzzleId                                                FEN  \
# 0       p0003  2R5/3rq1k1/p6p/1p3pNQ/Pb2p3/4P2P/5PP1/6K1 w - ...
# 1       p0027  7r/2b2pk1/Q4np1/p2pp1R1/qp3P2/1N6/1PP4P/4R2K b...
# 2       p0025  5qk1/p1pR1p2/1b3Rp1/4r3/1r6/7P/PP4P1/1B1Q3K b ...
# 3       p0029  4rrk1/pp3pp1/2p5/6qb/P1PP4/4nRB1/1P1QN1B1/R5K1...
# 4       p0031  4r1k1/1qr3Bp/p3pPp1/1p2Q3/8/2P2p2/PP1R1PPP/6K1...
# ...       ...                                                ...
# 2277    p5605  2r1k3/1Q4pr/2n4p/3pq3/P5P1/6K1/1P5P/R1N2R2 w -...
# 2278    p5613  3k2Q1/1p1q4/1P5p/2P1p2P/3p1pP1/p2P4/7K/8 b - -...
# 2279    p5609  q5rk/1b3p1p/pp2pPpQ/8/4P1P1/BPp1R3/P6P/6K1 b -...
# 2280    p5611   8/1p6/p3r3/2p1Ppkp/5rp1/PPPPR1K1/8/7R b - - 3 38
# 2281    p5607  1q4k1/1b2br1p/pQ4p1/1p3P2/8/4B2R/PP2B1PP/3Nn2K...
#
#                                         Moves
# 0                         c8e8 e7g5 e8g8 g7g8
# 1               e5f4 g5g6 g7g6 e1g1 g6f5 b3d4
# ...

# %%
import os

path = "dir_path/model_name.extension"
model_name = os.path.splitext(os.path.basename(path))[0]
print(model_name)  # Output: model_name
# Out:
# model_name
